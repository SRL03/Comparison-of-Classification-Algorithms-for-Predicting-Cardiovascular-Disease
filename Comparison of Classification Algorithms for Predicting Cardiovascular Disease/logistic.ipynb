# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
df =pd.read_csv('cardio.csv',sep=';')

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df["bmi"] = (df["weight"]/ (df["height"]/100)**2)

# %%
df["age"] = df["age"]/365

# %%
df["age"] = df["age"].astype("int")

# %%
df["height"] = df["height"]/100

# %%
df['pulse_pressure'] = df['ap_hi'] - df['ap_lo']

# %%
df=df.drop(['id'],axis=1)

# %%
df["gender"] = df["gender"] % 2

# %%
df
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50       0    1.68    62.0    110     80            1     1      0
# 1       55       1    1.56    85.0    140     90            3     1      0
# 2       51       1    1.65    64.0    130     70            3     1      0
# 3       48       0    1.69    82.0    150    100            1     1      0
# 4       47       1    1.56    56.0    100     60            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995   52       0    1.68    76.0    120     80            1     1      1
# 69996   61       1    1.58   126.0    140     90            2     2      0
# 69997   52       0    1.83   105.0    180     90            3     1      0
# 69998   61       1    1.63    72.0    135     80            1     2      0
# 69999   56       1    1.70    72.0    120     80            2     1      0
#
#        alco  active  cardio        bmi  pulse_pressure
# ...

# %%
x = df[['age','gender','height','weight','ap_hi','ap_lo','cholesterol','gluc','smoke','alco','active','bmi','pulse_pressure']]

# %%
x
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50       0    1.68    62.0    110     80            1     1      0
# 1       55       1    1.56    85.0    140     90            3     1      0
# 2       51       1    1.65    64.0    130     70            3     1      0
# 3       48       0    1.69    82.0    150    100            1     1      0
# 4       47       1    1.56    56.0    100     60            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995   52       0    1.68    76.0    120     80            1     1      1
# 69996   61       1    1.58   126.0    140     90            2     2      0
# 69997   52       0    1.83   105.0    180     90            3     1      0
# 69998   61       1    1.63    72.0    135     80            1     2      0
# 69999   56       1    1.70    72.0    120     80            2     1      0
#
#        alco  active        bmi  pulse_pressure
# ...

# %%
y = df['cardio']

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
xtrain , xtest ,ytrain , ytest = train_test_split (x,y, test_size=.3,random_state=1)

# %%
xtrain
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 23561   44       0    1.69    71.0    100     80            1     1      1
# 34858   40       1    1.58    69.0    140     80            2     1      0
# 54953   56       1    1.64    65.0    120     80            1     1      0
# 59230   45       1    1.53    53.0    100     60            1     1      0
# 1730    57       1    1.59    71.0    140     90            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 49100   58       0    1.75    78.0    120     80            1     1      0
# 20609   52       1    1.64    68.0    120     80            1     1      0
# 21440   49       0    1.78    82.0    120     80            1     1      0
# 50057   60       1    1.69    77.0    120     80            1     1      0
# 5192    56       1    1.74    65.0    160     90            2     2      0
#
#        alco  active        bmi  pulse_pressure
# ...

# %%
xtest
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 6670    44       1    1.53    93.0    140     90            1     1      0
# 49567   39       1    1.57    89.0    120     80            1     1      0
# 50796   54       1    1.65    66.0    150     90            1     1      0
# 22310   49       0    1.76    88.0    160    100            2     2      1
# 54037   46       0    1.65    78.0    140     90            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 15691   50       1    1.70    70.0    120     80            1     1      0
# 25200   57       1    1.65    60.0    120     70            3     1      0
# 7366    40       1    1.70    68.0    100     60            1     1      0
# 56399   60       1    1.65    66.0    110     80            1     1      0
# 31206   57       1    1.63    64.0    120     80            1     1      0
#
#        alco  active        bmi  pulse_pressure
# ...

# %%
logistic = LogisticRegression()

# %%
logistic.fit(xtrain,ytrain)
# Out:
# C:\Users\Samran Rahman\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
logistic.score(xtest,ytest)
# Out:
# 0.7186666666666667

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_score_logistic = cross_val_score(logistic,x,y,cv=10)
# Out:
# C:\Users\Samran Rahman\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Samran Rahman\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Samran Rahman\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Samran Rahman\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
cv_score_logistic
# Out:
# array([0.71689759, 0.71257143, 0.72271429, 0.72842857, 0.71657143,
#        0.72071429, 0.72357143, 0.72957143, 0.71942857, 0.71595942])

# %%
cv_score_logistic.mean()
# Out:
# 0.7206428437405246

# %%
pred_logistic = logistic.predict(xtest)

# %%
pred_logistic
# Out:
# array([1, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,pred_logistic)
# Out:
# 0.7186666666666667

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(ytest,pred_logistic)
# Out:
# array([[7991, 2361],
#        [3547, 7101]], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(ytest,pred_logistic))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73     10352
#            1       0.75      0.67      0.71     10648
#
#     accuracy                           0.72     21000
#    macro avg       0.72      0.72      0.72     21000
# weighted avg       0.72      0.72      0.72     21000

# %%
logistic_probs = logistic.predict_proba(xtest)
logistic_probs = logistic_probs[:, 1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
logistic_auc = roc_auc_score(ytest, logistic_probs)

# %%
print('Logistic: AUROC = %.3f' % (logistic_auc))
# Out:
# Logistic: AUROC = 0.786

# %%
logistic_fpr, logistic_tpr, _ = roc_curve(ytest, logistic_probs)

# %%
plt.plot(logistic_fpr, logistic_tpr, marker='.', label='LR(AUROC = %0.3f)' % logistic_auc)
plt.title('ROC Plot')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend() 
plt.show()
